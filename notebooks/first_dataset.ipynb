# %%
conditions, experiment_conditions, experiments, logcs, properties, response_properties, responses, source = import_data()

# %%
data_merged = merge_data(conditions, experiment_conditions, experiments, logcs, properties, response_properties, responses, source)

# %%
data_merged
# Out:
#         ResponseID  ExperimentID  Spec_rate  RateMethod     MethodID  \
# 0            38694       39472.0    0.01713         NaN  plate_count
# 1            38694       39472.0    0.01713         NaN  plate_count
# 2            38694       39472.0    0.01713         NaN  plate_count
# 3            38694       39472.0    0.01713         NaN  plate_count
# 4            38694       39472.0    0.01713         NaN  plate_count
# ...            ...           ...        ...         ...          ...
# 484891       60418           NaN        NaN         NaN          NaN
# 484892       60418           NaN        NaN         NaN          NaN
# 484893       60418           NaN        NaN         NaN          NaN
# 484894       60418           NaN        NaN         NaN          NaN
# 484895       60418           NaN        NaN         NaN          NaN
#
#        OrganismID OrganismSpecification Comment  Logc0  LogcVar  ...  \
# 0              ah   Strain(s): CECT-398     NaN    NaN     4.71  ...
# 1              ah   Strain(s): CECT-398     NaN    NaN     4.71  ...
# 2              ah   Strain(s): CECT-398     NaN    NaN     4.71  ...
# 3              ah   Strain(s): CECT-398     NaN    NaN     4.71  ...
# 4              ah   Strain(s): CECT-398     NaN    NaN     4.71  ...
# ...           ...                   ...     ...    ...      ...  ...
# 484891        NaN                   NaN     NaN    NaN      NaN  ...
# 484892        NaN                   NaN     NaN    NaN      NaN  ...
# 484893        NaN                   NaN     NaN    NaN      NaN  ...
# 484894        NaN                   NaN     NaN    NaN      NaN  ...
# 484895        NaN                   NaN     NaN    NaN      NaN  ...
#
#         Temperature LinkId  UserId PropertyID Value_x  ComBaseID_x      ID  \
# 0               1.5    A_1     NaN        NaN     NaN          NaN       1
# 1               1.5    A_1     NaN        NaN     NaN          NaN       2
# 2               1.5    A_1     NaN        NaN     NaN          NaN       3
# 3               1.5    A_1     NaN        NaN     NaN          NaN       4
# 4               1.5    A_1     NaN        NaN     NaN          NaN       5
# ...             ...    ...     ...        ...     ...          ...     ...
# 484891          NaN    NaN     NaN        NaN     NaN          NaN  419495
# 484892          NaN    NaN     NaN        NaN     NaN          NaN  419496
# 484893          NaN    NaN     NaN        NaN     NaN          NaN  419497
# 484894          NaN    NaN     NaN        NaN     NaN          NaN  419498
# 484895          NaN    NaN     NaN        NaN     NaN          NaN  419499
#
#           Time Value_y       ComBaseID_y
# 0         0.00    4.02               A_1
# 1        22.50    3.99               A_1
# 2        97.75    3.94               A_1
# 3       117.50    3.92               A_1
# 4       144.25    3.78               A_1
# ...        ...     ...               ...
# 484891    6.50    5.43  Lm_paneer_40C_T2
# 484892   17.00    6.70  Lm_paneer_40C_T2
# 484893   21.00    7.51  Lm_paneer_40C_T2
# 484894   24.00    7.79  Lm_paneer_40C_T2
# 484895   30.00    7.78  Lm_paneer_40C_T2
#
# [484896 rows x 27 columns]

# %%
cleaned_data = clean_data(data_merged,
                          min_time_threshold=5,
                          max_time_threshold=504,
                          min_temp_threshold=0,
                          max_temp_threshold=30)
